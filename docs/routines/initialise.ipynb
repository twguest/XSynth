# %%
import numpy as np
from datetime import datetime

from kickercontrol.device import (KL2005, KMX1938, KMX1965, KNY1938, KNY1965)

# %%
kickers = [KL2005, KMX1938, KMX1965, KNY1938, KNY1965]
for kicker in kickers:
	k = kicker()
	np.save("/System/Volumes/Data/home/xfeloper/user/guestt/FD_09-11-24/stored/" + k.__name__+"_" +str(datetime.now()), k.read_dac())

# %%
# Out:
# 'KL2005_2024-11-09 16:01:59.351380'
