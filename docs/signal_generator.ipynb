# %%
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint as print
from kickercontrol.signal import DACSignalGenerator
from kickercontrol.device import (KickerDevice,KL2005, KMX1938, KMX1965, KNY1938, KNY1965)

# %%
dac_generator = DACSignalGenerator(KL2005(), beamline = None )

dac_generator.set_oscillator('sin')
default_values = dac_generator.default_values
variables = dac_generator.variables

dac_generator.update_variable(V0 = 800, V1 = 1200, V2 = 0, V3 = 1, V4 = 1/400)
plt.plot(dac_generator.t,dac_generator.generate_signal())

# %%
np.argmin(abs(dac_generator.t+650))
# Out:
# 0

# %%
signal = dac_generator.generate_signal()/32767
grad_signal = np.gradient(signal)

# %%
dac_generator

# %%
plt.plot(grad_signal*30 > 1)
#plt.plot(signal)
