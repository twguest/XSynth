# %%
# %load_ext autoreload
# %autoreload 2

from xsynth.main import SetADAPT
from xsynth.device import ADAPT_MLS
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
SetADAPT(server = ADAPT_MLS(beam_region = 'SA2'),
                value = 1,
                beam_region = 'SA2',
                all_messages = True)
